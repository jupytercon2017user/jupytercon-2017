# %%
# !sudo pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading autocorrect-0.3.0.tar.gz (3.6MB)
#     100% |################################| 3.6MB 153kB/s
# Building wheels for collected packages: autocorrect
#   Running setup.py bdist_wheel for autocorrect
#   Stored in directory: /root/.cache/pip/wheels/72/d5/4d/8e8160e7f68c7899fb150d8dd666a9fa2a73fdf7a51dd2d756
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-0.3.0
# You are using pip version 7.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d
from copy import copy
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML

# %matplotlib inline

def tfidf_example():
    return pd.DataFrame({'Superman Wiki':
     {'Superman':'high','the':'medium','Apples':'low'},
 'Apple Wiki':
     {'Superman':'low','the':'medium','Apples':'high'}})



def highlight_words_in_text(text, words):
    random_id = np.random.choice(xrange(100000))
    textid = 'text{}'.format(random_id)
    words = [str(i.lemma_) for i in nlp(unicode(words))]
    spacy_text = nlp(unicode(text))

    text = spacy_text.text
    
    dynamic = ""
    
    for token in spacy_text:
        if token.lemma_ in words:
            start, stop = token.idx, token.idx + len(token)
            dynamic += """  var innerHTML = inputText.innerHTML;
                            \n innerHTML = innerHTML.substring(0,{} + adjuster) + "<span class='highlight'>" + innerHTML.substring({} + adjuster,{} + adjuster) + "</span>" + innerHTML.substring({} + adjuster); 
                            adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
                            inputText.innerHTML = innerHTML;
                            """.format(*[start, start, stop, stop])
                

    div = "<div id='{}'>{}</div><br>".format(*[textid,text])


    css = "<style>.highlight{background-color:yellow;}</style>"
    
    javascript = """
    <script>

    inputText = document.getElementById('{}');
    var innerHTML = inputText.innerHTML;
    var adjuster = 0;
    {} 
    </script>
    """.format(*[textid, dynamic])


    html = '<html><body>{} {} {}</body>'.format(*[div, css, javascript])
    
    return html

        

def plot_vector_graph():
    from sklearn.feature_extraction.text import CountVectorizer
    documents = {
        'doc1' : 'Welcome to weekly book review',
        'doc2' : 'This isnt news, but the president discusses his favorite book',
        'query' : 'In the news today the president said'}
    doc_names = ['doc1','doc2','query']
    doc_texts = [documents[name] for name in doc_names]

    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(doc_texts).todense()
    vocabulary = vectorizer.get_feature_names()

    idx = [vocabulary.index(i) for i in ['news','president','book']]
    X_subset = np.array([X[:, i] for i in idx]).reshape((3,3)).T


    class Arrow3D(FancyArrowPatch):
        def __init__(self, x, y, z, *args, **kwargs):
            FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
            self._verts3d = x, y, z

        def draw(self, renderer):
            xs3d, ys3d, zs3d = self._verts3d
            xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
            self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
            FancyArrowPatch.draw(self, renderer)


    fig = plt.figure(figsize=(12,12))
    ax = fig.add_subplot(111, projection='3d')

    defaults = {
        "mutation_scale":20,
        "lw":3,
        "arrowstyle":"->",
        "color":"red"}

    specials = {
        0:{'color':'blue'},
        1:{'color':'red'},
        2:{'color':'black'}}

    zeroes = np.zeros(3)
    artists = []
    for i in xrange(3):
        vector = X_subset[i]
        coordinates = zip(zeroes, vector)
        defaults.update(specials[i])

        arrow = Arrow3D(*coordinates, **defaults)
        ax.add_artist(arrow)
        artists.append(arrow)


    distance_coords = zip(X_subset[1], X_subset[2])
    defaults['alpha'] = .1
    defaults['color'] = 'red'
    defaults['linestyle'] = 'dashed'
    distance_arrow = Arrow3D(*distance_coords, **defaults)
    ax.add_artist(distance_arrow)
    artists.append(distance_arrow)
    
    
    distance_coords = zip(X_subset[0], X_subset[2])
    defaults['alpha'] = .1
    defaults['color'] = 'blue'
    defaults['linestyle'] = 'dashed'
    distance_arrow = Arrow3D(*distance_coords, **defaults)
    ax.add_artist(distance_arrow)
    artists.append(distance_arrow)    
    
    texts = [documents[i] for i in doc_names]
    texts.append("Distance between Doc 1 and Query")
    texts.append("Distance between Doc 2 and Query")

    ax.set_xlabel('news'), ax.set_ylabel('president'), ax.set_zlabel('books')
    ax.set_zticks([0, 1]), ax.set_xticks([0, 1]), ax.set_yticks([0, 1])  
    ax.legend(artists, texts)
    return ax
    #plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
import spacy
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import autocorrect

#create the processing function
def process(document):
    """
    Parameters
    ----------
    document: str
        The document we want to process
        
    Returns
    ----------
    
    """
    #create spacy object
    
    spacy_doc = nlp(unicode(document), parse=False, entity=False)
    
    #grab the lemma for each token in the document
    processed_tokens = map(lambda token: token.lemma_ if token.lemma_ != '-PRON-' else 'we', spacy_doc)
    
    #join lemmas to a string
    result = " ".join(processed_tokens)
    return result

#create a language model that uses the custom tokenizer
nlp = spacy.load('en')

# %%
#pass in the process function to sklearns vectorizer
toDTM = CountVectorizer(preprocessor=process)


documents = [
'Welcome to weekly book review',
'This isnt news, but the president discusses his favorite book',
'In the news today the president said'
]

DTM = toDTM.fit_transform(documents).todense()
words = toDTM.get_feature_names()

summary = pd.DataFrame(DTM, columns = words, index = documents)
summary
# Out:
#                                                     be  book  but  discuss  \
# Welcome to weekly book review                        0     1    0        0
# This isnt news, but the president discusses his...   1     1    1        1
# In the news today the president said                 0     0    0        0
#
#                                                     favorite  his  in  news  \
# Welcome to weekly book review                              0    0   0     0
# This isnt news, but the president discusses his...         1    1   0     1
# In the news today the president said                       0    0   1     1
#
#                                                     not  president  review  \
# Welcome to weekly book review                         0          0       1
# This isnt news, but the president discusses his...    1          1       0
# In the news today the president said                  0          1       0
#
#                                                     say  the  this  to  today  \
# Welcome to weekly book review                         0    0     0   1      0
# This isnt news, but the president discusses his...    0    1     1   0      0
# In the news today the president said                  1    2     0   0      1
#
#                                                     weekly  welcome
# Welcome to weekly book review                            1        1
# This isnt news, but the president discusses his...       0        0
# In the news today the president said                     0        0

# %%
plot_vector_graph()

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def getMostSimilarSentence(query, documents):
    """
    Transforms query into vector, and computes cosine similarity 
    of query vector against training documents.
    
    Parameters
    ----------
    query:                (string) document to compare
    vectorizer:            sklearn vectorizer class 
    document_term_matrix: (pandas.DataFrame) table of 
                          term instances in each document
                          
    Returns
    -------
    most similar document (string)
    """
    #create vectorizer and use it to build dtm
    vectorizer = CountVectorizer(preprocessor=process)
    dtm = vectorizer.fit_transform(documents).todense()
    
    #transform query to vector
    query_vector = encodeQuery(query, vectorizer)
    
    #compute similarities
    similarities = computeSimilarities(query_vector, dtm)
    
    #grab most similar document
    closest_idx = getMostSimilarIdx(similarities)
    return documents[closest_idx]

def encodeQuery(query, vectorizer):
    
    #transform query to vector
    query_vector = vectorizer.transform([query]).todense()
    return query_vector

def computeSimilarities(query_vector, dtm):
    
    #compute similarities
    all_vectors = np.concatenate((dtm, query_vector))
    similarities = cosine_similarity(all_vectors)[-1][:-1]
    return similarities

def getMostSimilarIdx(similarities):
    #grab most similar document
    return np.argmax(similarities)

# %%
from nltk.corpus import reuters

def get_document(fileid):
    return [" ".join(i) for i in reuters.sents(fileid)]

fileids = np.random.choice(reuters.fileids(), size=1000, replace=False)
raw_documents = map(get_document, fileids)

query = 'what are the sugar prices today'

# %%
query_results = getMostSimilarSentence(query, raw_documents)

# %%
HTML(highlight_words_in_text(" ".join(query_results), query))
# Out:
# <html><body><div id='text78104'>ALGERIAN , SPANISH FIRMS AGREE QUICKSILVER PRICE Algerian and Spanish producers which together meet 40 pct of the Western market ' s needs in quicksilver have agreed to apply a minimum selling price of 300 dlrs per unit , the Algerian news agency APS said . The agreement was made during a meeting here last week between Algeria ' s Entreprise Nationale des Non - ferreux et Substances Utiles ( ENOF ) and Spain ' s Almaden to discuss the market situation . The two firms " took note with regret that prices quoted by some specialised publications do not reflect the reality of the whole market since they take into account only part of the deals made ," a statement by ENOF said . The result is that the prices quoted are far away from two firms ' production costs . " They have thus decided that their selling price would not be linked any more to the prices quoted by these publications and that sales would be made at a minimum price of 300 dlrs fob per jar , which is close to their production cost ," the statement said . It added that Turkish producers would join in when the two firms meet again in Madrid later this month . The price of quicksilver on the London Metal Exchange hovered around 200 dlrs this week .</div><br> <style>.highlight{background-color:yellow;}</style>
#     <script>
#
#     inputText = document.getElementById('text78104');
#     var innerHTML = inputText.innerHTML;
#     var adjuster = 0;
#       var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,43 + adjuster) + "<span class='highlight'>" + innerHTML.substring(43 + adjuster,48 + adjuster) + "</span>" + innerHTML.substring(48 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,110 + adjuster) + "<span class='highlight'>" + innerHTML.substring(110 + adjuster,113 + adjuster) + "</span>" + innerHTML.substring(113 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,193 + adjuster) + "<span class='highlight'>" + innerHTML.substring(193 + adjuster,198 + adjuster) + "</span>" + innerHTML.substring(198 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,222 + adjuster) + "<span class='highlight'>" + innerHTML.substring(222 + adjuster,225 + adjuster) + "</span>" + innerHTML.substring(225 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,258 + adjuster) + "<span class='highlight'>" + innerHTML.substring(258 + adjuster,261 + adjuster) + "</span>" + innerHTML.substring(261 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,272 + adjuster) + "<span class='highlight'>" + innerHTML.substring(272 + adjuster,275 + adjuster) + "</span>" + innerHTML.substring(275 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,435 + adjuster) + "<span class='highlight'>" + innerHTML.substring(435 + adjuster,438 + adjuster) + "</span>" + innerHTML.substring(438 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,458 + adjuster) + "<span class='highlight'>" + innerHTML.substring(458 + adjuster,461 + adjuster) + "</span>" + innerHTML.substring(461 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,501 + adjuster) + "<span class='highlight'>" + innerHTML.substring(501 + adjuster,507 + adjuster) + "</span>" + innerHTML.substring(507 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,563 + adjuster) + "<span class='highlight'>" + innerHTML.substring(563 + adjuster,566 + adjuster) + "</span>" + innerHTML.substring(566 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,578 + adjuster) + "<span class='highlight'>" + innerHTML.substring(578 + adjuster,581 + adjuster) + "</span>" + innerHTML.substring(581 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,637 + adjuster) + "<span class='highlight'>" + innerHTML.substring(637 + adjuster,640 + adjuster) + "</span>" + innerHTML.substring(640 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,682 + adjuster) + "<span class='highlight'>" + innerHTML.substring(682 + adjuster,685 + adjuster) + "</span>" + innerHTML.substring(685 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,693 + adjuster) + "<span class='highlight'>" + innerHTML.substring(693 + adjuster,695 + adjuster) + "</span>" + innerHTML.substring(695 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,701 + adjuster) + "<span class='highlight'>" + innerHTML.substring(701 + adjuster,704 + adjuster) + "</span>" + innerHTML.substring(704 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;

# %% [markdown]
# ### TFIDF Vectors
# $\text{tfidf}_t = \text{Term Frequency}_t \cdot \frac{1}{\text{Document Frequency}_t} =tf_t \cdot \frac{1}{log\frac{df_t}{N}}$

# %%
tfidf_example()
# Out:
#          Apple Wiki Superman Wiki
# Apples         high           low
# Superman        low          high
# the          medium        medium

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(preprocessor=process, stop_words=None)
dtm = vectorizer.fit_transform(raw_documents).todense()
vocabulary = vectorizer.get_feature_names()

#grab the idf values of words in the query
words_in_query = process(query).split(" ")
idx = [vocabulary.index(i) for i in words]
idf_values = [vectorizer.idf_[i] for i in idx]

#plot the idf values for each word
ax = pd.Series(idf_values, index = words).plot(kind = 'bar')
ax.grid()
plt.show()

# %%
#transform query to vector
query_vector = encodeQuery(query, vectorizer)

#compute similarities
similarities = computeSimilarities(query_vector, dtm)

#grab most similar document
closest_idx = getMostSimilarIdx(similarities)
closest_document = raw_documents[closest_idx]

# %%
HTML(highlight_words_in_text(" ".join(closest_document), query))
# Out:
# <html><body><div id='text93945'>SUGAR OFFERED TO DUTCH INTERVENTION REFUSED The 2 , 500 tonnes of sugar offered to intervention in the Netherlands has been refused by the intervention board because of wrong packaging , a spokeswoman for the Ministry of Agriculture said . She said the sugar could be offered again to intervention . EC producers have threatened to sell over 800 , 000 tonnes of sugar to intervention stocks as a protest against EC export licensing policies . Last month Dutch traders said the sugar on offer in the Netherlands was Belgian , but the ministry could not confirm this .</div><br> <style>.highlight{background-color:yellow;}</style>
#     <script>
#
#     inputText = document.getElementById('text93945');
#     var innerHTML = inputText.innerHTML;
#     var adjuster = 0;
#       var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,0 + adjuster) + "<span class='highlight'>" + innerHTML.substring(0 + adjuster,5 + adjuster) + "</span>" + innerHTML.substring(5 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,44 + adjuster) + "<span class='highlight'>" + innerHTML.substring(44 + adjuster,47 + adjuster) + "</span>" + innerHTML.substring(47 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,66 + adjuster) + "<span class='highlight'>" + innerHTML.substring(66 + adjuster,71 + adjuster) + "</span>" + innerHTML.substring(71 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,99 + adjuster) + "<span class='highlight'>" + innerHTML.substring(99 + adjuster,102 + adjuster) + "</span>" + innerHTML.substring(102 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,119 + adjuster) + "<span class='highlight'>" + innerHTML.substring(119 + adjuster,123 + adjuster) + "</span>" + innerHTML.substring(123 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,135 + adjuster) + "<span class='highlight'>" + innerHTML.substring(135 + adjuster,138 + adjuster) + "</span>" + innerHTML.substring(138 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,205 + adjuster) + "<span class='highlight'>" + innerHTML.substring(205 + adjuster,208 + adjuster) + "</span>" + innerHTML.substring(208 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,249 + adjuster) + "<span class='highlight'>" + innerHTML.substring(249 + adjuster,252 + adjuster) + "</span>" + innerHTML.substring(252 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,253 + adjuster) + "<span class='highlight'>" + innerHTML.substring(253 + adjuster,258 + adjuster) + "</span>" + innerHTML.substring(258 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,265 + adjuster) + "<span class='highlight'>" + innerHTML.substring(265 + adjuster,267 + adjuster) + "</span>" + innerHTML.substring(267 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,362 + adjuster) + "<span class='highlight'>" + innerHTML.substring(362 + adjuster,367 + adjuster) + "</span>" + innerHTML.substring(367 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,473 + adjuster) + "<span class='highlight'>" + innerHTML.substring(473 + adjuster,476 + adjuster) + "</span>" + innerHTML.substring(476 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,477 + adjuster) + "<span class='highlight'>" + innerHTML.substring(477 + adjuster,482 + adjuster) + "</span>" + innerHTML.substring(482 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,495 + adjuster) + "<span class='highlight'>" + innerHTML.substring(495 + adjuster,498 + adjuster) + "</span>" + innerHTML.substring(498 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,511 + adjuster) + "<span class='highlight'>" + innerHTML.substring(511 + adjuster,514 + adjuster) + "</span>" + innerHTML.substring(514 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#                               var innerHTML = inputText.innerHTML;
#
#  innerHTML = innerHTML.substring(0,529 + adjuster) + "<span class='highlight'>" + innerHTML.substring(529 + adjuster,532 + adjuster) + "</span>" + innerHTML.substring(532 + adjuster);
#                             adjuster = adjuster + innerHTML.length - inputText.innerHTML.length
#                             inputText.innerHTML = innerHTML;
#
#     </script>
#     </body>
