# %% [markdown]
# ### Environment for Tutorial
#
# **Everyone: Make sure you have a github account!**
#
# If you do not have one, please go to <a href="http://www.github.com">www.github.com</a> and register.
#
# ### First 25 Attendees:
#
#
# * navigate to nsf.datascience.com
# * Login with your username and password.
# * Enter "JupyterCon 2017" Project.
# * Go to Settings
# ![Session](assets/Settings.png)
# * Click "Git Integrations"
# * Click "ADD CREDENTIALS"
# * Enter "github" in "Choose a provider", then "Connect"
# * Enter your github credentials.
#
#
#
#
# ![Session](assets/LoggingIn.png)
#
#
# ### Remaining Attendees:
#
# * Install git: https://git-scm.com/book/en/v2/Getting-Started-Installing-Git
# * https://github.com/aikramer2/docker-stacks

# %%
# !pip3 install keras

# %%
# !sudo pip3 install spacy
# Out:
# Downloading/unpacking spacy
# ...
#   Running setup.py (path:/tmp/pip_build_root/spacy/setup.py) egg_info for package spacy
#
# ...
# Downloading/unpacking murmurhash>=0.26,<0.27 (from spacy)
# ...
#   Running setup.py (path:/tmp/pip_build_root/murmurhash/setup.py) egg_info for package murmurhash
#
# Downloading/unpacking cymem>=1.30,<1.32 (from spacy)
# ...
#   Running setup.py (path:/tmp/pip_build_root/cymem/setup.py) egg_info for package cymem
#
#     package init file 'cymem/tests/__init__.py' not found (or not a regular file)
# Downloading/unpacking preshed>=1.0.0,<2.0.0 (from spacy)
# ...
#   Running setup.py (path:/tmp/pip_build_root/preshed/setup.py) egg_info for package preshed
#
# Downloading/unpacking thinc>=6.5.0,<6.6.0 (from spacy)
# ...
#   Running setup.py (path:/tmp/pip_build_root/thinc/setup.py) egg_info for package thinc
#
# ...
# Downloading/unpacking plac>=0.9.6,<1.0.0 (from spacy)
# ...
# Downloading/unpacking pathlib (from spacy)
# ...
