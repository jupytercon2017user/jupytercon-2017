# %%
# !pip install jupyter_dashboards

# %%
# !jupyter nbextension install --py jupyter_dashboards --user --sys-prefix
# Out:
# Installing /opt/conda/envs/python3/lib/python3.5/site-packages/jupyter_dashboards/nbextension -> jupyter_dashboards
# Making directory: /opt/conda/envs/python3/share/jupyter/nbextensions/jupyter_dashboards/
# Traceback (most recent call last):
#   File "/opt/conda/envs/python3/bin/jupyter-nbextension", line 6, in <module>
#     sys.exit(notebook.nbextensions.main())
#   File "/opt/conda/envs/python3/lib/python3.5/site-packages/jupyter_core/application.py", line 267, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/envs/python3/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/conda/envs/python3/lib/python3.5/site-packages/notebook/nbextensions.py", line 900, in start
#     super(NBExtensionApp, self).start()
#   File "/opt/conda/envs/python3/lib/python3.5/site-packages/jupyter_core/application.py", line 256, in start
#     self.subapp.start()
#   File "/opt/conda/envs/python3/lib/python3.5/site-packages/notebook/nbextensions.py", line 678, in start
#     self.install_extensions()
#   File "/opt/conda/envs/python3/lib/python3.5/site-packages/notebook/nbextensions.py", line 657, in install_extensions
#     **kwargs
#   File "/opt/conda/envs/python3/lib/python3.5/site-packages/notebook/nbextensions.py", line 225, in install_nbextension_python
#     destination=dest, logger=logger
#   File "/opt/conda/envs/python3/lib/python3.5/site-packages/notebook/nbextensions.py", line 192, in install_nbextension
#     os.makedirs(dest_dir)
#   File "/opt/conda/envs/python3/lib/python3.5/os.py", line 241, in makedirs
#     mkdir(name, mode)
# PermissionError: [Errno 13] Permission denied: '/opt/conda/envs/python3/share/jupyter/nbextensions/jupyter_dashboards/'

# %%
# !jupyter nbextension enable jupyter_dashboards --user --py
# Out:
# Enabling notebook extension jupyter_dashboards/notebook/main...
#       - Validating: OK

# %%
# %matplotlib notebook

# %%
# %%html
# <style>
# .ui-dialog-titlebar {
#     display: none;
# }
#
# .mpl-message {
#     display: none;
# }
# </style>
# Out:
# <style>
# .ui-dialog-titlebar {
#     display: none;
# }
#
# .mpl-message {
#     display: none;
# }
# </style>

# %%
import matplotlib.pyplot as plt
import numpy

x = numpy.random.beta(1, 0.8, 100)
y = numpy.random.beta(0.1, 0.5, 100)

# %%
fig, ax = plt.subplots(figsize=(5,3.5))
ax.scatter(x, y)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %%
from ipywidgets import *
from IPython.display import display

w = IntSlider()
display(w)

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
